# %% [markdown]
# # TASK 6: Prediction using Decision Tree Algorithm
#
# # Author: Apoorva Mishra
#
# ### GRIPJAN21 @ The Sparks Foundation

# %% [raw]
# The main task on this dataset is to create an iris (name of a flower) classifier based on a given properties that are the sepal and petal size. The purpose of this task is if we feed any new data to this classifier, it would be able to predict the right class accordingly.
# Decision Trees are versatile Machine Learning algorithms that can perform both classification and regression tasks, and even multioutput tasks.For the given ‘Iris’ dataset, I created the Decision Tree classifier and visualized it graphically.

# %% [markdown]
# ### Importing Libraries

# %%
# %matplotlib inline
import sklearn.datasets as datasets
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

import warnings
warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# ### Importing dataset

# %%
iris=datasets.load_iris()

# %%
data = pd.read_csv('iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB

# %% [markdown]
# ### Data Visualization comparing various features¶

# %%
sns.pairplot(data, hue='Species')

# %% [markdown]
# ### Splitting the Dataset

# %%
#separating dependent and independent varibales
X = data.drop(columns = ['Species','Id'])
Y = data['Species']

# %%
#Scaling the dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
#splitting the dataset
from sklearn.model_selection import train_test_split as tts
x_train, x_test, y_train, y_test = tts(X, Y, train_size = 0.80,random_state = 1, stratify = Y)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((120, 4), (30, 4), (120,), (30,))

# %% [markdown]
# ## Model Building, predictions

# %%
from sklearn.tree import DecisionTreeClassifier as DTC
classifier = DTC( class_weight = 'balanced')
classifier = DTC()

# %%
classifier.fit(x_train, y_train)
predicted_values = classifier.predict(x_train)
print('Decision Tree Classifer Created')
# Out:
# Decision Tree Classifer Created

# %%
predicted_values[:30]
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa'],
#       dtype=object)

# %%
classifier.score(x_test, y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# ### Evaluation Metrics

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train, predicted_values))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        40
# Iris-versicolor       1.00      1.00      1.00        40
#  Iris-virginica       1.00      1.00      1.00        40
#
#     avg / total       1.00      1.00      1.00       120

# %%
predicted_values = classifier.predict(x_test)
print(classification_report(y_test, predicted_values))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.91      1.00      0.95        10
#  Iris-virginica       1.00      0.90      0.95        10
#
#     avg / total       0.97      0.97      0.97        30

# %% [markdown]
# # Visualising Decision Tree

# %%
# Import necessary libraries for graph viz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Visualize the graph
dot_data = StringIO()
export_graphviz(classifier, out_file=dot_data, feature_names=iris.feature_names,  
                filled=True, rounded=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# ### Predicting the class output for some random values of petal and sepal length and width

# %% [raw]
# Estimating Class Probabilities for flower whose petals length width are 4.7cm and 3.2cm and sepal length and width are 1.3cm and 0.2cm.

# %%
print("Class Names = ",iris.target_names)
print('Output = ',classifier.predict([[4.7, 3.2, 1.3, 0.2]]))
# Out:
# Class Names =  ['setosa' 'versicolor' 'virginica']
# Output =  ['Iris-setosa']

# %% [raw]
# Our model predicts the class as 0, that is, setosa.

# %% [markdown]
# ### Model accuracy

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, predicted_values)
print("Confusion Matrix:")
print(result)
print("Accuracy:",accuracy_score(y_test, predicted_values))
# Out:
# Confusion Matrix:
# [[10  0  0]
#  [ 0 10  0]
#  [ 0  1  9]]
# Accuracy: 0.9666666666666667

# %% [raw]
# The accuracy of this model is 0.96 or 96% since I have taken all the 4 features of the iris dataset for creating the decision tree model.

# %% [markdown]
# ## CONCLUSION

# %% [raw]
# I was able to successfully carry-out prediction using Prediction using Decision Tree Algorithm and was able to evaluate the model's accuracy score.
